# %% [markdown]
# ### Phils marshallpalmer.py

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

D=np.arange(0,5,0.1)
Dmm=D
Dcm=D*0.1
N0=0.08*1.e6*1.e-1 #m**{-3} mm^{-1}
R=1.
theLambda=41*R**(-0.21)
curve1=N0*np.exp(-theLambda*Dcm)
R=5.
theLambda=41*R**(-0.21)
curve2=N0*np.exp(-theLambda*Dcm)
R=15.
theLambda=41*R**(-0.21)
curve3=N0*np.exp(-theLambda*Dcm)
fig, ax = plt.subplots(1,1,figsize=(10,8))
ax.semilogy(D,curve1,label='1 mm/hr')
ax.semilogy(D,curve2,'r-',label='5 mm/hr')
ax.semilogy(D,curve3,'g-',label='25 mm/hr')
ax.set_xlabel('Drop diameter (mm)')
ax.set_ylabel('$n(D) m^{-3} mm^{-1}$')
ax.set_title('Marshall Palmer distribution for three rain rates')
ax.legend(loc='best')

# %% [markdown]
# ### Hadleigh's solution:

# %%
# flux of water at a given rain rate

def fall_speed(drop_dia):
    """
    fall velocity for drop of diameter 'drop_dia'
    """
    g = 9.81  #m/s^2
    rho_air = 1. #kg/m^3
    rho_l = 1000. #kg/m^3
    return np.sqrt((rho_l / rho_air)*g*drop_dia)


D=np.arange(0,5,0.1)
Dmm=D
Dcm=D*0.1
N0=0.08*1.e6*1.e-1 #m**{-3} mm^{-1}
R=15.
theLambda=41*R**(-0.21)
curve1=N0*np.exp(-theLambda*Dcm)

drop_speeds = [(fall_speed(diameter*1.e-3)) for diameter in Dmm]  # m/s

drop_volume = [(((4./3.)*np.pi*((diameter*1.e-3)**3))/1000.) for diameter in Dmm]

"""
fig, ax = plt.subplots(1,1,figsize=(10,8))
ax.semilogy(D,curve1,label='15 mm/hr')
ax.set_xlabel('Drop diameter (mm)')
ax.set_ylabel('$n(D) m^{-3} mm^{-1}$')
ax.set_title('Marshall Palmer distribution for 15mm/hour rainrate')
ax.legend(loc='best')
"""
# Out:
# "\nfig, ax = plt.subplots(1,1,figsize=(10,8))\nax.semilogy(D,curve1,label='15 mm/hr')\nax.set_xlabel('Drop diameter (mm)')\nax.set_ylabel('$n(D) m^{-3} mm^{-1}$')\nax.set_title('Marshall Palmer distribution for 15mm/hour rainrate')\nax.legend(loc='best')\n"
